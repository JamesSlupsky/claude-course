# %%
# LOAD ENV VARIABLES
from dotenv import load_dotenv
load_dotenv()

# CREATE API CLIENT
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# Define some helper functions

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)

    return message.content[0].text

# %%
# With system prompt
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
answer = chat(messages, system=system)
answer
# Out:
# "Let's work through this step by step!\n\nYour goal is to get **x by itself** on one side of the equation.\n\n**First, let's look at the equation:**\n5x + 3 = 2\n\n**Step 1:** Can you think about what we should do first to start isolating x? \n\n*Hint: There's a number being **added** to the 5x term. What could we do to remove it?*"
